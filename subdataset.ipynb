# %%
import pandas as pd
import missingno

# %%
df_target = pd.read_csv('UFPI-NCAD-IoT-Attacks-all-v1.csv', sep=';', low_memory=False)

# %%
df_target[df_target['frame.time_delta'] == 'frame.time_delta']
# Out:
#         frame.time_delta frame.time_epoch frame.time_relative ipv6.plen  \
# 670052  frame.time_delta        ipv6.plen            ipv6.nxt  ipv6.src
#
#         ipv6.nxt     ipv6.src     ipv6.dst tcp.srcport tcp.dstport    eth.src  \
# 670052  ipv6.dst  tcp.srcport  tcp.dstport     eth.src     eth.dst  frame.len
#
#         ... mqtt.msgtype  mqtt.passwd    mqtt.qos     mqtt.retain  \
# 670052  ...     mqtt.qos  mqtt.retain  mqtt.topic  mqtt.topic_len
#
#            mqtt.topic mqtt.topic_len   mqtt.username mqtt.willmsg  \
# 670052  mqtt.username   mqtt.willmsg  mqtt.willtopic        label
#
#        mqtt.willtopic label
# 670052            NaN   NaN
#
# [1 rows x 30 columns]

# %%
df_target.iloc[:670052].to_csv('first_dataset.csv', index = False)

# %%
df_target.iloc[670052:].drop(columns=['mqtt.willtopic', 'label'], axis=1).to_csv('second_dataset.csv', header=False, index=False)

# %%
df = df_target.iloc[:670052]

# %%
df['label'].unique()
# Out:
# array(['normal', 'bruteforce', 'DoS'], dtype=object)

# %%
df
# Out:
#        frame.time_delta           frame.time_epoch  frame.time_relative  \
# 0           0.000000000  1.573.757.292.769.270.000          0.000000000
# 1           0.000023000  1.573.757.292.769.290.000          0.000023000
# 2           0.003886000  1.573.757.292.773.170.000          0.003909000
# 3           0.000010000  1.573.757.292.773.180.000          0.003919000
# 4         3.287.798.000  1.573.757.296.060.980.000        3.291.717.000
# ...                 ...                        ...                  ...
# 670047      0.002997000  1.574.035.197.120.260.000  277.904.350.995.000
# 670048      0.000010000  1.574.035.197.120.270.000  277.904.351.005.000
# 670049      0.809234000  1.574.035.197.929.500.000  277.905.160.239.000
# 670050      0.000023000  1.574.035.197.929.530.000  277.905.160.262.000
# 670051      0.002982000  1.574.035.197.932.510.000  277.905.163.244.000
#
#        ipv6.plen ipv6.nxt                              ipv6.src  \
# 0             68        6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 1             20        6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 2             64        6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 3             20        6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 4             68        6  fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b
# ...          ...      ...                                   ...
# 670047        64        6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 670048        20        6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 670049        68        6  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 670050        20        6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 670051        64        6  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
#
#                                     ipv6.dst tcp.srcport tcp.dstport  \
# 0       fd9e:6c51:2336:0:717b:e02b:9c00:d43a       50728        1883
# 1       fd9e:6c51:2336:0:6201:94ff:fe0e:877a        1883       50728
# 2       fd9e:6c51:2336:0:717b:e02b:9c00:d43a       50728        1883
# 3       fd9e:6c51:2336:0:6201:94ff:fe0e:877a        1883       50728
# 4       fd9e:6c51:2336:0:717b:e02b:9c00:d43a       60066        1883
# ...                                      ...         ...         ...
# 670047  fd9e:6c51:2336:0:717b:e02b:9c00:d43a       50746        1883
# 670048  fd9e:6c51:2336:0:6201:94ff:fe0e:877a        1883       50746
# 670049  fd9e:6c51:2336:0:717b:e02b:9c00:d43a       62795        1883
# 670050  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91        1883       62795
# 670051  fd9e:6c51:2336:0:717b:e02b:9c00:d43a       62795        1883
#
#                   eth.src  ... mqtt.msgtype mqtt.passwd mqtt.qos mqtt.retain  \
# 0       60:01:94:0e:87:7a  ...            3         NaN        0           1
# 1       68:a3:c4:6e:50:12  ...          NaN         NaN      NaN         NaN
# 2       60:01:94:0e:87:7a  ...            3         NaN        0           1
# 3       68:a3:c4:6e:50:12  ...          NaN         NaN      NaN         NaN
# 4       cc:50:e3:1c:2a:5b  ...            3         NaN        0           1
# ...                   ...  ...          ...         ...      ...         ...
# 670047  60:01:94:0e:87:7a  ...            3         NaN        0           1
# 670048  68:a3:c4:6e:50:12  ...          NaN         NaN      NaN         NaN
# 670049  cc:50:e3:55:cd:91  ...            3         NaN        0           1
# 670050  68:a3:c4:6e:50:12  ...          NaN         NaN      NaN         NaN
# 670051  cc:50:e3:55:cd:91  ...            3         NaN        0           1
#
#                                      mqtt.topic mqtt.topic_len mqtt.username  \
# 0       ufpi/ppgcc/esp-dht22-node07/temperatura             39           NaN
# 1                                           NaN            NaN           NaN
# 2           ufpi/ppgcc/esp-dht22-node07/umidade             35           NaN
# 3                                           NaN            NaN           NaN
# 4       ufpi/ppgcc/esp-dht22-node03/temperatura             39           NaN
# ...                                         ...            ...           ...
# 670047      ufpi/ppgcc/esp-dht22-node07/umidade             35           NaN
# 670048                                      NaN            NaN           NaN
# 670049  ufpi/ppgcc/esp-dht22-node01/temperatura             39           NaN
# 670050                                      NaN            NaN           NaN
# 670051      ufpi/ppgcc/esp-dht22-node01/umidade             35           NaN
#
#        mqtt.willmsg mqtt.willtopic   label
# 0               NaN            NaN  normal
# 1               NaN            NaN  normal
# 2               NaN            NaN  normal
# 3               NaN            NaN  normal
# 4               NaN            NaN  normal
# ...             ...            ...     ...
# 670047          NaN            NaN  normal
# 670048          NaN            NaN  normal
# 670049          NaN            NaN  normal
# 670050          NaN            NaN  normal
# 670051          NaN            NaN  normal
#
# [670052 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670052 entries, 0 to 670051
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   frame.time_delta     670052 non-null  object
#  1   frame.time_epoch     670052 non-null  object
#  2   frame.time_relative  670052 non-null  object
#  3   ipv6.plen            670052 non-null  int64
#  4   ipv6.nxt             670052 non-null  int64
#  5   ipv6.src             670052 non-null  object
#  6   ipv6.dst             670052 non-null  object
#  7   tcp.srcport          666728 non-null  float64
#  8   tcp.dstport          666728 non-null  float64
#  9   eth.src              670052 non-null  object
#  10  eth.dst              670052 non-null  object
#  11  frame.len            670052 non-null  int64
#  12  frame.number         670052 non-null  int64
#  13  mqtt.clientid        157 non-null     object
#  14  mqtt.dupflag         320484 non-null  object
#  15  mqtt.hdrflags        429628 non-null  object
#  16  mqtt.kalive          2790 non-null    float64
#  17  mqtt.len             429628 non-null  object
#  18  mqtt.msg             285215 non-null  object
#  19  mqtt.msgid           211297 non-null  object
#  20  mqtt.msgtype         429628 non-null  object
#  21  mqtt.passwd          2692 non-null    object
#  22  mqtt.qos             320484 non-null  object
#  23  mqtt.retain          320484 non-null  object
#  24  mqtt.topic           320581 non-null  object
#  25  mqtt.topic_len       320581 non-null  object
#  26  mqtt.username        2692 non-null    object
#  27  mqtt.willmsg         98 non-null      float64
#  28  mqtt.willtopic       98 non-null      object
#  29  label                670052 non-null  object
# dtypes: float64(4), int64(4), object(22)
# memory usage: 153.4+ MB

# %%
df_=pd.read_csv('second_dataset.csv', low_memory=False)
df_concat = pd.concat([df, df_])

# %%
missingno.bar(df_concat)
