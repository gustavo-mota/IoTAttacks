# %% [markdown]
# # Libraries

# %%
import pandas as pd
import missingno

# %% [markdown]
# # Read first_dataset.csv generated by subdataset notebook

# %%
df = pd.read_csv('first_dataset.csv', low_memory=False, parse_dates=True)

# %% [markdown]
# # Initial Analysis

# %% [markdown]
# ## Calculate correlation between frame delta and packet lenght

# %%
#There's exaclty one value in this column that goes beyond a  float64 which is weird but is ignored
frame_delta = pd.to_numeric(df['frame.time_delta'], errors='coerce') 
packet_lenght = df['ipv6.plen']

correlation = frame_delta[:5].corr(packet_lenght[:5])
print(correlation)
# Out:
# 0.5227321184479206

# %% [markdown]
# ### The correlation isn't here, so the packet lenght probably does not affect the delay between packets, which makes sense since the packet size should be more or less the same, if the message is very big it gets fragmented in different packets
