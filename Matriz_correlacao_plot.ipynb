# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read dataset

# %%
for word in ['first', 'second']:
    exec('df_{} = pd.read_csv("{}_dataset.csv", low_memory=False)'.format(word, word))

# %%
df = pd.concat([df_first, df_second])

# %% [markdown]
# # Correlation matrix

# %%
corr = df.corr()
corr.dropna(how='all', inplace=True)
corr.dropna(how='all', axis=1, inplace=True)
corr.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col0 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col4 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col5 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col0 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col4 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow4_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col0 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col1 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col2 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col3 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col4 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow5_col6 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col0 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col2 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col4 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow6_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ipv6.plen</th>        <th class="col_heading level0 col1" >ipv6.nxt</th>        <th class="col_heading level0 col2" >tcp.srcport</th>        <th class="col_heading level0 col3" >tcp.dstport</th>        <th class="col_heading level0 col4" >frame.len</th>        <th class="col_heading level0 col5" >frame.number</th>        <th class="col_heading level0 col6" >mqtt.kalive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15blevel0_row0" class="row_heading level0 row0" >ipv6.plen</th>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col1" class="data row0 col1" >-0.077343</td>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col2" class="data row0 col2" >0.239248</td>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col3" class="data row0 col3" >-0.342250</td>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_bed7cbd2_d99b_11ea_af48_6d6bf38fe15brow0_col5" class="data row0 col5" >-0.029778</td>
#                         <td

# %%
sns.pairplot(df.drop(columns = ['mqtt.willmsg']))
