# %% [markdown]
# # Introdução
#
# O dataset foi obtido no [Kaagle](https://www.kaggle.com/jmessiasalves/ufpi-ncad-iot-attacks) e é sobre ataques em redes IoT.
#
# ## Questões interessantes para serem analisadas no dataset
#
#  - Analisar como os ataques funcionam.
#  - Entender o comportamento.
#  - Prever ataques.
#  - Analisar possíveis correlações não exploradas.
#
# ### Equipe
#  - Igor Melo
#  - Jarélio Filho
#  - Leyberson Assunção
#  - Gustavo Mota
#  - Eduardo Linhares
#
# #### bibliotecas extras
#  - missingno
#  - seaborn
#  - os

# %% [markdown]
# # 1 - Conhecendo os dados
# # 1.1 - Leitura dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno
import os
import seaborn as sns

# %matplotlib inline

# %%
if 'UFPI-NCAD-IoT-Attacks-all-v1.csv' not in os.listdir():
    # !unzip 578734_1047033_bundle_archive.zip

# %%
df_description = pd.read_csv('UFPI-NCAD-IoT-Attacks-all-v1-Description.txt', sep='|')
# pd.read_csv('UFPI-NCAD-IoT-Attacks-all-v1.csv', sep=';')

# There is two actual ways to read the dataset
path = 'UFPI-NCAD-IoT-Attacks-all-v1.csv'
df_target = pd.read_csv(path, sep=';', low_memory=False)
#df_target = pd.read_csv(path,sep=';', engine='python')

# %% [markdown]
# # 1.2 - Análise Inicial
# Aqui observamos pela primeira vez os dados e identificamos:
#
# - O que significam os dados armazenados
# - Os tipos dos dados
# - Volume de dados NaNs
# - Problema no dataset

# %%
df_description
# Out:
#                   FIELD                                        DESCRIPTION   \
# 0      frame.time_delta    Time difference compared to the previous capt...
# 1      frame.time_epoch                Full time in the form of timestamp
# 2   frame.time_relative             Time since the first package was sent
# 3             ipv6.plen                               IPv6 Payload length
# 4              ipv6.nxt                                       Next Header
# 5              ipv6.src                                Source IPv6 address
# 6              ipv6.dst                           Destination IPv6 address
# 7           tcp.srcport                                        Source Port
# 8           tcp.dstport                                   Destination Port
# 9               eth.src                                  Source MAC address
# 10              eth.dst                            Destination MAC address
# 11            frame.len                                     Frame length
# 12         frame.number                                     Frame number
# 13        mqtt.clientid                                          Client ID
# 14         mqtt.dupflag                            Duplicate message flag
# 15        mqtt.hdrflags                                       Header flags
# 16          mqtt.kalive                                         Keep Alive
# 17             mqtt.len                                Message length mqtt
# 18             mqtt.msg                                      Topic content
# 19           mqtt.msgid                                         Message ID
# 20         mqtt.msgtype                                  Message type mqtt
# 21          mqtt.passwd                                           Password
# 22             mqtt.qos                                          QoS level
# 23          mqtt.retain            If the message is retained for a period
# 24           mqtt.topic                                         Topic name
# 25       mqtt.topic_len                                 Topic content size
# 26        mqtt.username                                           Username
# 27         mqtt.willmsg                             Retained topic content
# 28       mqtt.willtopic                               Topic name retained
# 29                label                                              class
#
#                     TYPE
# 0              timestamp
# 1              timestamp
# 2              timestamp
# 3     numerical, 2 bytes
# 4      numerical, 1 byte
# 5    nominal-categorical
# 6    nominal-categorical
# 7     numerical, 2 bytes
# 8     numerical, 2 bytes
# 9    nominal-categorical
# 10   nominal-categorical
# 11    numerical, 4 bytes
# 12    numerical, 4 bytes
# 13   nominal-categorical
# 14              boolean
# 15     numerical, 1 byte
# 16    numerical, 2 bytes
# 17    numerical, 8 bytes
# 18   nominal-categorical
# 19    numerical, 2 bytes
# 20     numerical, 1 byte
# 21   nominal-categorical
# 22     numerical, 1 byte
# 23              boolean
# 24   nominal-categorical
# 25    numerical, 2 bytes
# 26   nominal-categorical
# 27   nominal-categorical
# 28   nominal-categorical
# 29   nominal-categorical

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015646 entries, 0 to 1015645
# Data columns (total 30 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   frame.time_delta     1015646 non-null  object
#  1   frame.time_epoch     1015646 non-null  object
#  2   frame.time_relative  1015646 non-null  object
#  3   ipv6.plen            1015646 non-null  object
#  4   ipv6.nxt             1015646 non-null  object
#  5   ipv6.src             956463 non-null   object
#  6   ipv6.dst             956463 non-null   object
#  7   tcp.srcport          1012322 non-null  object
#  8   tcp.dstport          1012322 non-null  object
#  9   eth.src              1015646 non-null  object
#  10  eth.dst              1015646 non-null  object
#  11  frame.len            670481 non-null   object
#  12  frame.number         810230 non-null   object
#  13  mqtt.clientid        142482 non-null   object
#  14  mqtt.dupflag         320913 non-null   object
#  15  mqtt.hdrflags        571953 non-null   object
#  16  mqtt.kalive          120410 non-null   object
#  17  mqtt.len             430725 non-null   object
#  18  mqtt.msg             427540 non-null   object
#  19  mqtt.msgid           211492 non-null   object
#  20  mqtt.msgtype         569806 non-null   object
#  21  mqtt.passwd          142870 non-null   object
#  22  mqtt.qos             461210 non-null   object
#  23  mqtt.retain          461210 non-null   object
#  24  mqtt.topic           320776 non-null   object
#  25  mqtt.topic_len       320582 non-null   object
#  26  mqtt.username        2693 non-null     object
#  27  mqtt.willmsg         345692 non-null   object
#  28  mqtt.willtopic       98 non-null       object
#  29  label                670052 non-null   object
# dtypes: object(30)
# memory usage: 232.5+ MB

# %%
df_target
# Out:
#         frame.time_delta           frame.time_epoch frame.time_relative  \
# 0            0.000000000  1.573.757.292.769.270.000         0.000000000
# 1            0.000023000  1.573.757.292.769.290.000         0.000023000
# 2            0.003886000  1.573.757.292.773.170.000         0.003909000
# 3            0.000010000  1.573.757.292.773.180.000         0.003919000
# 4          3.287.798.000  1.573.757.296.060.980.000       3.291.717.000
# ...                  ...                        ...                 ...
# 1015641      0.000010000                         20                   6
# 1015642   10.003.192.000                         68                   6
# 1015643      0.000023000                         20                   6
# 1015644      0.013353000                         64                   6
# 1015645      0.000010000                         20                   6
#
#                                     ipv6.plen  \
# 0                                          68
# 1                                          20
# 2                                          64
# 3                                          20
# 4                                          68
# ...                                       ...
# 1015641  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 1015642  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 1015643  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 1015644  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 1015645  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
#
#                                      ipv6.nxt  \
# 0                                           6
# 1                                           6
# 2                                           6
# 3                                           6
# 4                                           6
# ...                                       ...
# 1015641  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 1015642  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 1015643  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 1015644  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 1015645  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
#
#                                      ipv6.src  \
# 0        fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 1        fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 2        fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 3        fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 4        fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b
# ...                                       ...
# 1015641                                  1883
# 1015642                                 59172
# 1015643                                  1883
# 1015644                                 59172
# 1015645                                  1883
#
#                                      ipv6.dst        tcp.srcport  \
# 0        fd9e:6c51:2336:0:717b:e02b:9c00:d43a              50728
# 1        fd9e:6c51:2336:0:6201:94ff:fe0e:877a               1883
# 2        fd9e:6c51:2336:0:717b:e02b:9c00:d43a              50728
# 3        fd9e:6c51:2336:0:6201:94ff:fe0e:877a               1883
# 4        fd9e:6c51:2336:0:717b:e02b:9c00:d43a              60066
# ...                                       ...                ...
# 1015641                                 59172  68:a3:c4:6e:50:12
# 1015642                                  1883  cc:50:e3:55:cd:91
# 1015643                                 59172  68:a3:c4:6e:50:12
# 1015644                                  1883  cc:50:e3:55:cd:91
# 1015645                                 59172  68:a3:c4:6e:50:12
#
#                tcp.dstport            eth.src  ... mqtt.msgtype mqtt.passwd  \
# 0                     1883  60:01:94:0e:87:7a  ...            3         NaN
# 1                    50728  68:a3:c4:6e:50:12  ...          NaN         NaN
# 2                     1883  60:01:94:0e:87:7a  ...            3         NaN
# 3                    50728  68:a3:c4:6e:50:12  ...          NaN         NaN
# 4                     1883  cc:50:e3:1c:2a:5b  ...            3         NaN
# ...                    ...                ...  ...          ...         ...
# 1015641  cc:50:e3:55:cd:91                 74  ...          NaN         NaN
# 1015642  68:a3:c4:6e:50:12                122  ...            0           1
# 1015643  cc:50:e3:55:cd:91                 74  ...          NaN         NaN
# 1015644  68:a3:c4:6e:50:12                118  ...            0           1
# 1015645  cc:50:e3:55:cd:91                 74  ...          NaN         NaN
#
#                                         mqtt.qos mqtt.retain  \
# 0                                              0           1
# 1                                            NaN         NaN
# 2                                              0           1
# 3                                            NaN         NaN
# 4                                              0           1
# ...                                          ...         ...
# 1015641                                      NaN         NaN
# 1015642  ufpi/ppgcc/esp-dht22-node01/temperatura          39
# 1015643                                      NaN         NaN
# 1015644      ufpi/ppgcc/esp-dht22-node01/umidade          35
# 1015645                                      NaN         NaN
#
#                                       mqtt.topic mqtt.topic_len mqtt.username  \
# 0        ufpi/ppgcc/esp-dht22-node07/temperatura             39           NaN
# 1                                            NaN            NaN           NaN
# 2            ufpi/ppgcc/esp-dht22-node07/umidade             35           NaN
# 3                                            NaN            NaN           NaN
# 4        ufpi/ppgcc/esp-dht22-node03/temperatura             39           NaN
# ...                                          ...            ...           ...
# 1015641                                      NaN            NaN           NaN
# 1015642                                      NaN            NaN           NaN
# 1015643                                      NaN            NaN           NaN
# 1015644                                      NaN            NaN           NaN
# 1015645                                      NaN            NaN           NaN
#
#         mqtt.willmsg mqtt.willtopic   label
# 0                NaN            NaN  normal
# 1                NaN            NaN  normal
# 2                NaN            NaN  normal
# 3                NaN            NaN  normal
# 4                NaN            NaN  normal
# ...              ...            ...     ...
# 1015641       normal            NaN     NaN
# 1015642       normal            NaN     NaN
# 1015643       normal            NaN     NaN
# 1015644       normal            NaN     NaN
# 1015645       normal            NaN     NaN
#
# [1015646 rows x 30 columns]

# %%
miss = missingno.bar(df_target)

# %%
df_target.label.value_counts()
# Out:
# normal        429768
# DoS           213956
# bruteforce     26328
# Name: label, dtype: int64

# %% [markdown]
# # 1.3 - Resolvendo o problema de transposição de colunas
#
# Identificamos que o problema é que são dois datasets juntos em que o segundo não possui duas das colunas do primeiro. Há um cabeçalho em uma linha específica. Dividimos os dois, concatenamos e refazemos a última análise.
#
# Na próxima célula, percebemos uma linha que contém um novo cabeçalho. Esta é a linha que começa o segundo dataset. Na duas células seguintes, perceberá
#
# &nbsp; &nbsp; 1. Um shift dos valores das colunas.
#
# &nbsp; &nbsp; 2. A contagem de valores na coluna ipv6.src mostrando a diferença entre os valores existentes. Além disso há uma mudança no padrão dos elementos nessa coluna. Um endereço ipv6 não tem as caracteristicas dos apresentados no final do output. Na verdade, os valores ao final são característicos de outro tipo de endereço.

# %%
df_target[df_target['frame.time_delta'] == 'frame.time_delta']
# Out:
#         frame.time_delta frame.time_epoch frame.time_relative ipv6.plen  \
# 670052  frame.time_delta        ipv6.plen            ipv6.nxt  ipv6.src
#
#         ipv6.nxt     ipv6.src     ipv6.dst tcp.srcport tcp.dstport    eth.src  \
# 670052  ipv6.dst  tcp.srcport  tcp.dstport     eth.src     eth.dst  frame.len
#
#         ... mqtt.msgtype  mqtt.passwd    mqtt.qos     mqtt.retain  \
# 670052  ...     mqtt.qos  mqtt.retain  mqtt.topic  mqtt.topic_len
#
#            mqtt.topic mqtt.topic_len   mqtt.username mqtt.willmsg  \
# 670052  mqtt.username   mqtt.willmsg  mqtt.willtopic        label
#
#        mqtt.willtopic label
# 670052            NaN   NaN
#
# [1 rows x 30 columns]

# %%
df_target[['frame.time_delta', 'frame.time_epoch', 'frame.time_relative']]
# Out:
#         frame.time_delta           frame.time_epoch frame.time_relative
# 0            0.000000000  1.573.757.292.769.270.000         0.000000000
# 1            0.000023000  1.573.757.292.769.290.000         0.000023000
# 2            0.003886000  1.573.757.292.773.170.000         0.003909000
# 3            0.000010000  1.573.757.292.773.180.000         0.003919000
# 4          3.287.798.000  1.573.757.296.060.980.000       3.291.717.000
# ...                  ...                        ...                 ...
# 1015641      0.000010000                         20                   6
# 1015642   10.003.192.000                         68                   6
# 1015643      0.000023000                         20                   6
# 1015644      0.013353000                         64                   6
# 1015645      0.000010000                         20                   6
#
# [1015646 rows x 3 columns]

# %%
df_target['ipv6.src'].value_counts()
# Out:
# fd9e:6c51:2336:0:717b:e02b:9c00:d43a    332999
# 1883                                    143361
# fd9e:6c51:2336:0:b043:1759:1f44:81e8    109120
# fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91     35589
# fd9e:6c51:2336:0:6201:94ff:fe0e:877a     35583
#                                          ...
# 60596                                        1
# 60509                                        1
# 60786                                        1
# 60361                                        1
# 60638                                        1
# Name: ipv6.src, Length: 295, dtype: int64

# %% [markdown]
# ## 1.3.1 Como nossa correção funciona
# Primeiro, gravamos o primeiro dataset separadamente em um arquivo. Em seguida, repetimos o processo para o segundo dataset. Por fim, fazemos a leitura dos dois e concatenamos.
#
# As duas células abaixo são respectivamente a separação e escrita dos datasets e a leitura e concatenação. Caso você já tenha os datasets separados, pode executar apenas a célula seguinte.

# %%
# Spliting and Writing
df_target.iloc[:670052].to_csv('first_dataset.csv', index = False)
df_target.iloc[670052:].drop(columns=['mqtt.willtopic', 'label'], axis=0).to_csv('second_dataset.csv', header=False, index=False)
del df_target

# %%
# Reading and concatenating splited data
df = pd.read_csv('first_dataset.csv', low_memory=False)
df_= pd.read_csv('second_dataset.csv', low_memory=False)

df_concat = pd.concat([df, df_])

# %% [markdown]
# Nas três células abaixo certificamos a correção pela atualização do gráfico de missing values para verificar os valores mais apurados, contamos novamente os ataques por labels e observamos o dataset corrigido.

# %%
missingno.bar(df_concat)

# %%
df_concat["label"].value_counts()
# Out:
# normal         710331
# DoS            213956
# mitm            56060
# bruteforce      26328
# enumeration      8970
# Name: label, dtype: int64

# %%
df_concat
# Out:
#        frame.time_delta           frame.time_epoch frame.time_relative  \
# 0           0.000000000  1.573.757.292.769.270.000         0.000000000
# 1           0.000023000  1.573.757.292.769.290.000         0.000023000
# 2           0.003886000  1.573.757.292.773.170.000         0.003909000
# 3           0.000010000  1.573.757.292.773.180.000         0.003919000
# 4         3.287.798.000  1.573.757.296.060.980.000       3.291.717.000
# ...                 ...                        ...                 ...
# 345588      0.000010000                        NaN                 NaN
# 345589   10.003.192.000                        NaN                 NaN
# 345590      0.000023000                        NaN                 NaN
# 345591      0.013353000                        NaN                 NaN
# 345592      0.000010000                        NaN                 NaN
#
#         ipv6.plen  ipv6.nxt                              ipv6.src  \
# 0              68         6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 1              20         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 2              64         6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 3              20         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 4              68         6  fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b
# ...           ...       ...                                   ...
# 345588         20         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 345589         68         6  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 345590         20         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 345591         64         6  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 345592         20         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
#
#                                     ipv6.dst  tcp.srcport  tcp.dstport  \
# 0       fd9e:6c51:2336:0:717b:e02b:9c00:d43a      50728.0       1883.0
# 1       fd9e:6c51:2336:0:6201:94ff:fe0e:877a       1883.0      50728.0
# 2       fd9e:6c51:2336:0:717b:e02b:9c00:d43a      50728.0       1883.0
# 3       fd9e:6c51:2336:0:6201:94ff:fe0e:877a       1883.0      50728.0
# 4       fd9e:6c51:2336:0:717b:e02b:9c00:d43a      60066.0       1883.0
# ...                                      ...          ...          ...
# 345588  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91       1883.0      59172.0
# 345589  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      59172.0       1883.0
# 345590  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91       1883.0      59172.0
# 345591  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      59172.0       1883.0
# 345592  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91       1883.0      59172.0
#
#                   eth.src  ... mqtt.msgtype  mqtt.passwd  mqtt.qos  \
# 0       60:01:94:0e:87:7a  ...            3          NaN         0
# 1       68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 2       60:01:94:0e:87:7a  ...            3          NaN         0
# 3       68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 4       cc:50:e3:1c:2a:5b  ...            3          NaN         0
# ...                   ...  ...          ...          ...       ...
# 345588  68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 345589  cc:50:e3:55:cd:91  ...            3          NaN         0
# 345590  68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 345591  cc:50:e3:55:cd:91  ...            3          NaN         0
# 345592  68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
#
#        mqtt.retain                               mqtt.topic mqtt.topic_len  \
# 0                1  ufpi/ppgcc/esp-dht22-node07/temperatura             39
# 1              NaN                                      NaN            NaN
# 2                1      ufpi/ppgcc/esp-dht22-node07/umidade             35
# 3              NaN                                      NaN            NaN
# 4                1  ufpi/ppgcc/esp-dht22-node03/temperatura             39
# ...            ...                                      ...            ...
# 345588         NaN                                      NaN            NaN
# 345589           1  ufpi/ppgcc/esp-dht22-node01/temperatura             39
# 345590         NaN                                      NaN            NaN
# 345591           1      ufpi/ppgcc/esp-dht22-node01/umidade             35
# 345592         NaN                                      NaN            NaN
#
#         mqtt.username mqtt.willmsg mqtt.willtopic   label
# 0                 NaN          NaN            NaN  normal
# 1                 NaN          NaN            NaN  normal
# 2                 NaN          NaN            NaN  normal
# 3                 NaN          NaN            NaN  normal
# 4                 NaN          NaN            NaN  normal
# ...               ...          ...            ...     ...
# 345588            NaN          NaN            NaN  normal
# 345589            NaN          NaN            NaN  normal
# 345590            NaN          NaN            NaN  normal
# 345591            NaN          NaN            NaN  normal
# 345592            NaN          NaN            NaN  normal
#
# [1015645 rows x 30 columns]

# %% [markdown]
# # 2 - De volta para a análise de dados
# Aqui analisamos as correlações, exploramos a proporção de valores NaN no data set para futuras implicações e possíveis reparações de dados e algumas análises básicas.

# %% [markdown]
# # 2.1 Correlações

# %% [markdown]
# Nas três células abaixo, geramos e exibimos as matrizes de correlação. Porém, as matrizes valem para correlações lineares.

# %%
correOne = df.corr()
correTwo = df_.corr()

# %%
correOne
# Out:
#               ipv6.plen  ipv6.nxt  tcp.srcport  tcp.dstport  frame.len  \
# ipv6.plen      1.000000 -0.017090     0.275488    -0.388581   1.000000
# ipv6.nxt      -0.017090  1.000000          NaN          NaN  -0.017090
# tcp.srcport    0.275488       NaN     1.000000    -0.949253   0.275488
# tcp.dstport   -0.388581       NaN    -0.949253     1.000000  -0.388581
# frame.len      1.000000 -0.017090     0.275488    -0.388581   1.000000
# frame.number   0.192611 -0.024813    -0.044350    -0.050625   0.192611
# mqtt.kalive   -0.016409       NaN    -0.251209          NaN  -0.016409
# mqtt.willmsg        NaN       NaN          NaN          NaN        NaN
#
#               frame.number  mqtt.kalive  mqtt.willmsg
# ipv6.plen         0.192611    -0.016409           NaN
# ipv6.nxt         -0.024813          NaN           NaN
# tcp.srcport      -0.044350    -0.251209           NaN
# tcp.dstport      -0.050625          NaN           NaN
# frame.len         0.192611    -0.016409           NaN
# frame.number      1.000000    -0.003324           NaN
# mqtt.kalive      -0.003324     1.000000           NaN
# mqtt.willmsg           NaN          NaN           NaN

# %%
corre_final = df_concat.corr()
corre_final
# Out:
#               ipv6.plen  ipv6.nxt  tcp.srcport  tcp.dstport  frame.len  \
# ipv6.plen      1.000000 -0.077343     0.239248    -0.342250   1.000000
# ipv6.nxt      -0.077343  1.000000          NaN          NaN  -0.077343
# tcp.srcport    0.239248       NaN     1.000000    -0.956167   0.239248
# tcp.dstport   -0.342250       NaN    -0.956167     1.000000  -0.342250
# frame.len      1.000000 -0.077343     0.239248    -0.342250   1.000000
# frame.number  -0.029778  0.216727     0.007598     0.009210  -0.029778
# mqtt.kalive   -0.041068       NaN    -0.409065          NaN  -0.041068
# mqtt.willmsg        NaN       NaN          NaN          NaN        NaN
#
#               frame.number  mqtt.kalive  mqtt.willmsg
# ipv6.plen        -0.029778    -0.041068           NaN
# ipv6.nxt          0.216727          NaN           NaN
# tcp.srcport       0.007598    -0.409065           NaN
# tcp.dstport       0.009210          NaN           NaN
# frame.len        -0.029778    -0.041068           NaN
# frame.number      1.000000    -0.385293           NaN
# mqtt.kalive      -0.385293     1.000000           NaN
# mqtt.willmsg           NaN          NaN           NaN

# %% [markdown]
# ## Conclusões das correlações identificadas:
# - A matriz de correlações do dataset final ficou menor.
# - Vamos identificar posteriormente a proporção de NaNs em relação à quantidade de valores válidos. Os valores de NaNs importam para a identificação de um ataque, porque caracteristicamente nem todas as informações podem sequer existir.

# %% [markdown]
# # 2.1.1 Matrix de correlações

# %% [markdown]
# As correlações anteriores são lineraes, mas provavelmente correlações quadráticas, por exemplo, não seriam identificadas. Abaixo há um heatmap e uma matrix de correlações que nos mostra, scartterplots para identificar mais correlações possíveis.

# %%
corr = df_concat.corr()
corr.dropna(how='all', inplace=True)
corr.dropna(how='all', axis=1, inplace=True)
corr.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col0 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col4 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col5 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col0 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col4 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row4_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col0 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col1 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col2 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col3 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col4 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row5_col6 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col0 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col2 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col4 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1a9002fc_dab2_11ea_a07d_519bf23299c6row6_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ipv6.plen</th>        <th class="col_heading level0 col1" >ipv6.nxt</th>        <th class="col_heading level0 col2" >tcp.srcport</th>        <th class="col_heading level0 col3" >tcp.dstport</th>        <th class="col_heading level0 col4" >frame.len</th>        <th class="col_heading level0 col5" >frame.number</th>        <th class="col_heading level0 col6" >mqtt.kalive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6level0_row0" class="row_heading level0 row0" >ipv6.plen</th>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col1" class="data row0 col1" >-0.077343</td>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col2" class="data row0 col2" >0.239248</td>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col3" class="data row0 col3" >-0.342250</td>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_1a9002fc_dab2_11ea_a07d_519bf23299c6row0_col5" class="data row0 col5" >-0.029778</td>
#                         <td

# %%
corr = df_concat.corr()
corr.dropna(how='all', inplace=True)
corr.dropna(how='all', axis=1, inplace=True)
corr.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col0 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col4 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col5 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row1_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col0 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col4 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col5 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row3_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col2 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row4_col6 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col0 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col1 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col2 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col3 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col4 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row5_col6 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col0 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col2 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col4 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1ad27b96_dab2_11ea_a07d_519bf23299c6row6_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ipv6.plen</th>        <th class="col_heading level0 col1" >ipv6.nxt</th>        <th class="col_heading level0 col2" >tcp.srcport</th>        <th class="col_heading level0 col3" >tcp.dstport</th>        <th class="col_heading level0 col4" >frame.len</th>        <th class="col_heading level0 col5" >frame.number</th>        <th class="col_heading level0 col6" >mqtt.kalive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6level0_row0" class="row_heading level0 row0" >ipv6.plen</th>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col1" class="data row0 col1" >-0.077343</td>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col2" class="data row0 col2" >0.239248</td>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col3" class="data row0 col3" >-0.342250</td>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col4" class="data row0 col4" >1.000000</td>
#                         <td id="T_1ad27b96_dab2_11ea_a07d_519bf23299c6row0_col5" class="data row0 col5" >-0.029778</td>
#                         <td

# %%
sns.pairplot(df.drop(columns = ['mqtt.willmsg']))

# %% [markdown]
# Conclusões da matrix:

# %% [markdown]
# ## 2.1.2 Análises dos NaN
#
# A contagem de NaNs é importante para a análise dos ataques. Nas duas céulas abaixo há uma função para contagem absoluta de NaNs e a contagem para o primeiro, o segundo e o dataset final.

# %%
def nan_counter(dataframe): # Counts the values of NaN
  nan_counts = {}
  for column in dataframe.columns:
    nan_counts[column] = dict(dataframe[column].isna().value_counts())
  return nan_counts

nan_counter(df_concat)
# Out:
# {'frame.time_delta': {False: 1015645},
#  'frame.time_epoch': {False: 670052, True: 345593},
#  'frame.time_relative': {False: 670052, True: 345593},
#  'ipv6.plen': {False: 1015645},
#  'ipv6.nxt': {False: 1015645},
#  'ipv6.src': {False: 1015645},
#  'ipv6.dst': {False: 1015645},
#  'tcp.srcport': {False: 953138, True: 62507},
#  'tcp.dstport': {False: 953138, True: 62507},
#  'eth.src': {False: 1015645},
#  'eth.dst': {False: 1015645},
#  'frame.len': {False: 1015645},
#  'frame.number': {False: 1015645},
#  'mqtt.clientid': {True: 1015060, False: 585},
#  'mqtt.dupflag': {True: 554984, False: 460661},
#  'mqtt.hdrflags': {False: 571952, True: 443693},
#  'mqtt.kalive': {True: 1012427, False: 3218},
#  'mqtt.len': {False: 571952, True: 443693},
#  'mqtt.msg': {True: 612811, False: 402834},
#  'mqtt.msgid': {True: 803252, False: 212393},
#  'mqtt.msgtype': {False: 571952, True: 443693},
#  'mqtt.passwd': {True: 1012759, False: 2886},
#  'mqtt.qos': {True: 554984, False: 460661},
#  'mqtt.retain': {True: 554984, False: 460661},
#  'mqtt.topic': {True: 554339, False: 461306},
#  'mqtt.topic_len': {True: 554339, False: 461306},
#  'mqtt.username': {True: 1012759, False: 2886},
#  'mqtt.willmsg': {True: 1015547, False: 98},
#  'mqtt.willtopic': {True: 1015547, False: 98},
#  'label': {False: 1015645}}

# %%
nan_first = nan_counter(df)
nan_second = nan_counter(df_)

nan_final = nan_counter(df_concat)

# %% [markdown]
# O seguinte gráfico de barras

# %%
nan_final
# Out:
# {'frame.time_delta': {False: 1015645},
#  'frame.time_epoch': {False: 670052, True: 345593},
#  'frame.time_relative': {False: 670052, True: 345593},
#  'ipv6.plen': {False: 1015645},
#  'ipv6.nxt': {False: 1015645},
#  'ipv6.src': {False: 1015645},
#  'ipv6.dst': {False: 1015645},
#  'tcp.srcport': {False: 953138, True: 62507},
#  'tcp.dstport': {False: 953138, True: 62507},
#  'eth.src': {False: 1015645},
#  'eth.dst': {False: 1015645},
#  'frame.len': {False: 1015645},
#  'frame.number': {False: 1015645},
#  'mqtt.clientid': {True: 1015060, False: 585},
#  'mqtt.dupflag': {True: 554984, False: 460661},
#  'mqtt.hdrflags': {False: 571952, True: 443693},
#  'mqtt.kalive': {True: 1012427, False: 3218},
#  'mqtt.len': {False: 571952, True: 443693},
#  'mqtt.msg': {True: 612811, False: 402834},
#  'mqtt.msgid': {True: 803252, False: 212393},
#  'mqtt.msgtype': {False: 571952, True: 443693},
#  'mqtt.passwd': {True: 1012759, False: 2886},
#  'mqtt.qos': {True: 554984, False: 460661},
#  'mqtt.retain': {True: 554984, False: 460661},
#  'mqtt.topic': {True: 554339, False: 461306},
#  'mqtt.topic_len': {True: 554339, False: 461306},
#  'mqtt.username': {True: 1012759, False: 2886},
#  'mqtt.willmsg': {True: 1015547, False: 98},
#  'mqtt.willtopic': {True: 1015547, False: 98},
#  'label': {False: 1015645}}

# %%
# Barplot NaN
# Isso rodou no colab
def plot_doublebar(dicte):
    grupos = len(dicte)

    false = [value['False'] for value in dicte.values()]
    true = [value['True'] for value in dicte.values()]
    fig, ax = plt.subplots()
    indice = np.arange(grupos)
    bar_larg = 0.4
    transp = 0.7
    plt.bar(indice, false, bar_larg, alpha=transp, label='Value')
    plt.bar(indice + bar_larg, true, bar_larg, alpha=transp, label='NaN')

    plt.xlabel('Type') 
    plt.ylabel('Count') 
    plt.title('Values and NaN count per type') 
    plt.xticks(indice + bar_larg, (list(dicte.keys())), rotation=80)
    plt.legend() 
    #plt.tight_layout() 
    plt.show()

plot_doublebar(nan_second)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-f482141a5850> in <module>
#      21     plt.show()
#      22
# ---> 23 plot_doublebar(nan_second)
#
# <ipython-input-52-f482141a5850> in plot_doublebar(dicte)
#       4     grupos = len(dicte)
#       5
# ----> 6     false = [value['False'] for value in dicte.values()]
#       7     true = [value['True'] for value in dicte.values()]
#       8     fig, ax = plt.subplots()
#
# <ipython-input-52-f482141a5850> in <listcomp>(.0)
#       4     grupos = len(dicte)
#       5
# ----> 6     false = [value['False'] for value in dicte.values()]
#       7     true = [value['True'] for value in dicte.values()]
#       8     fig, ax = plt.subplots()
#
# KeyError: 'False'

# %% [markdown]
# Acima vemos novamente a proporção de NaNs comparado com a de valores existentes.
#
# mqtt.msg e mqtt.topic podem ter valor nenhum e ser um indício de ataques como: bruteforce e mitm, que somente se utilizam de mensagens de controle e conexão na rede, não contendo o conteúdo que um dispositivo padrão de uma rede IoT prôve ao broker. podemos fazer uma classificação nas mensagens de mqtt.msg para classfificá-la em ataques e não ataques fazendo análise das substrings.
#
# Os valores NaN podem ser causados por ataque. Portanto, podemos relacionar com mqtt.topic e trabalhar em uma predição como veremos mais adiante.

# %%
# Padrão esquisito
dstport = np.array(df_concat['tcp.dstport'].isna())
srcport = np.array(df_concat['tcp.srcport'].isna())

comparisson = np.where(dstport == srcport, dstport, srcport)

true_corr = np.count_nonzero(comparisson == True)
false_corr = np.count_nonzero(comparisson == False)

# False and true counts of dstport and srcport
tc_dst = np.count_nonzero(dstport == True)
tc_src = np.count_nonzero(srcport == True)
fc_dst = np.count_nonzero(dstport == False)
fc_src = np.count_nonzero(srcport == False)

print('Comparisson true:', true_corr,
      '\nComparisson false:', false_corr,
      '\ndstport true:', tc_dst,
      '\ndstport false:', fc_dst,
      '\nsrcport true:', tc_src,
      '\nsrcport false:', fc_src,
      '\nsize dstport:', len(dstport),
      '\nsize srcport:', len(srcport),
      '\nproportion comparisson both:', true_corr/false_corr,
      '\nproportion dstport both:', tc_dst/fc_dst,
      '\nproportion srcport both:', tc_src/fc_src,
      '\nproportion comparisson true:', true_corr/len(comparisson),
      '\nproportion comparisson false:', false_corr/len(comparisson),
      '\npropotion dstport true:', tc_dst/len(dstport),
      '\npropotion dstport false:', fc_dst/len(dstport),
      '\npropotion srcport true:', tc_src/len(srcport),
      '\npropotion srcport false:', fc_src/len(srcport)
)
# Out:
# Comparisson true: 62507
# Comparisson false: 953138
# dstport true: 62507
# dstport false: 953138
# srcport true: 62507
# srcport false: 953138
# size dstport: 1015645
# size srcport: 1015645
# proportion comparisson both: 0.06558022028289713
# proportion dstport both: 0.06558022028289713
# proportion srcport both: 0.06558022028289713
# proportion comparisson true: 0.06154414189997489
# proportion comparisson false: 0.9384558581000251
# propotion dstport true: 0.06154414189997489
# propotion dstport false: 0.9384558581000251
# propotion srcport true: 0.06154414189997489
# propotion srcport false: 0.9384558581000251

# %% [markdown]
# As colunas dstport e srcport, respectivamente, corresponde a porta de destino do pacote e a porta de saída do pacote.
#
# Existe uma forte correlação entre a porta de destino e a porta de saída como observado na matrix de correlações: -0.956167. Isso se deve ao fato de que comunicação em rede é feita de maneira padronizada com a mesma porta baixa sendo usada pelo broker e portas altas sendo usadas pelos dispostivos.
#
# Nós encontramos 62507 tuplas com valores NaN, isto se iguala à quantidade de valores NaN nas colunas srcport e dstport.
#
# Também percebemos que existem poucas tuplas com essas mesmas colunas NaN. Mas também suficientes para usarmos um algoritmo treinado e predizermos os valores faltantes.

# %%
# Adaptar para mqtt.msg mqtt.topic
dstport = np.array(df_concat['mqtt.msg'].isna())
srcport = np.array(df_concat['mqtt.topic'].isna())

comparisson = np.where(dstport == srcport, dstport, srcport)

true_corr = np.count_nonzero(comparisson == True)
false_corr = np.count_nonzero(comparisson == False)

# False and true counts of dstport and srcport
tc_dst = np.count_nonzero(dstport == True)
tc_src = np.count_nonzero(srcport == True)
fc_dst = np.count_nonzero(dstport == False)
fc_src = np.count_nonzero(srcport == False)

print('Comparisson true:', true_corr,
      '\nComparisson false:', false_corr,
      '\ndstport true:', tc_dst,
      '\ndstport false:', fc_dst,
      '\nsrcport true:', tc_src,
      '\nsrcport false:', fc_src,
      '\nsize dstport:', len(dstport),
      '\nsize srcport:', len(srcport),
      '\nproportion comparisson both:', true_corr/false_corr,
      '\nproportion dstport both:', tc_dst/fc_dst,
      '\nproportion srcport both:', tc_src/fc_src,
      '\nproportion comparisson true:', true_corr/len(comparisson),
      '\nproportion comparisson false:', false_corr/len(comparisson),
      '\npropotion dstport true:', tc_dst/len(dstport),
      '\npropotion dstport false:', fc_dst/len(dstport),
      '\npropotion srcport true:', tc_src/len(srcport),
      '\npropotion srcport false:', fc_src/len(srcport)
)
# Out:
# Comparisson true: 554339
# Comparisson false: 461306
# dstport true: 612811
# dstport false: 402834
# srcport true: 554339
# srcport false: 461306
# size dstport: 1015645
# size srcport: 1015645
# proportion comparisson both: 1.2016730760059484
# proportion dstport both: 1.5212494476633054
# proportion srcport both: 1.2016730760059484
# proportion comparisson true: 0.5457999596315641
# proportion comparisson false: 0.4542000403684358
# propotion dstport true: 0.6033712566890991
# propotion dstport false: 0.396628743310901
# propotion srcport true: 0.5457999596315641
# propotion srcport false: 0.4542000403684358

# %% [markdown]
# Vamos descobrir a proporção de ataques em dstport e srcport para conferir se corresponde à proporção de labels e identificar se o experimento segue os padrões de ataques ou está usando maneiras novas de promover um ataque # adicionar link sobre os ataques costumam ser em portas baixas de cliente, vamos verificar as dstport.

# %%
# identifica características para melhor avaliar a credibilidade do expe como
# a diversidade de portas dst e src usadas e como isso afeta

dst_counts = df_concat['tcp.dstport'].value_counts()
min = df_concat['tcp.dstport'].min()
max = df_concat['tcp.dstport'].max()
amp = max - min

mean = df_concat['tcp.dstport'].mean()
std = df_concat['tcp.dstport'].std()
mode = df_concat['tcp.dstport'].mode()
median = df_concat['tcp.dstport'].median()

src_counts = df_concat['tcp.srcport'].value_counts()
src_min = df_concat['tcp.srcport'].min()
src_max = df_concat['tcp.srcport'].max()
src_amp = src_max - src_min

src_mean = df_concat['tcp.srcport'].mean()
src_std = df_concat['tcp.srcport'].std()
src_mode = df_concat['tcp.srcport'].mode()
src_median = df_concat['tcp.srcport'].median()

cv_srcport = src_std/src_mean
cv_dstport = std/mean

dstcounts_df = dst_counts.rename_axis('ports').reset_index(name='counts')

tmp = dstcounts_df['counts'] == 1 # tmp = dstcounts_df['counts'].value_counts() == 1
unique = tmp.value_counts()[True] # número de portas usadas só uma vez

print('Max dstport value:', max, '. Min dstport value:', min,". Amplitude:",amp,". Mode:",mode,
      "\nMean of dstport values:", "{:.2f}".format(mean),". Standart deviation of dstport values:", "{:.2f}".format(std),". Median: ", median,

      '\n\nMax srcport value:', "{:.2f}".format(src_max), '. Min srcport value:', "{:.2f}".format(src_min),". Amplitude:",src_amp,". Mode:", src_mode,
      "\nMean of srcport values:", "{:.2f}".format(src_mean),". Standart deviation of srcport values:", "{:.2f}".format(src_std),". Median: ", src_median,

      "\n\nCoefficient of Variation from dstport:", "{:.2f}".format(cv_dstport)," from srcport:", "{:.2f}".format(cv_srcport),
      "\nNumber of ports used just one time:",unique)
# Out:
# Max dstport value: 62795.0 . Min dstport value: 1883.0 . Amplitude: 60912.0 . Mode: 0    1883.0
# dtype: float64
# Mean of dstport values: 27751.49 . Standart deviation of dstport values: 26555.60 . Median:  1883.0
#
# Max srcport value: 62795.00 . Min srcport value: 1883.00 . Amplitude: 60912.0 . Mode: 0    1883.0
# dtype: float64
# Mean of srcport values: 27902.81 . Standart deviation of srcport values: 26508.54 . Median:  34713.0
#
# Coefficient of Variation from dstport: 0.96  from srcport: 0.95
# Number of ports used just one time: 12

# %% [markdown]
# Tem muita porta diferente, o que indica uma variedade muito grande
#
# Observe que como estamos falando de portas e são praticamente discretas ao contrário de números como preços, a média e o desvio padrão apenas são úteis para calcular os coeficientes
#
# Poucas portas foram usadas uma só vez, é claro
#
# O que significa que o experimento tem alguma fidelidade nesse quesito pois uma rede IoT real um número certamente finito de portas sob ataque terá várias portas de cliente usadas mais de uma vez, pelo princípio da casa dos pombos

# %% [markdown]
# ## 2.1.3 Portas Mais e Menos Usadas

# %%
# Piechart portas mais e menos usadas e qtd

dstcounts_df = dst_counts.rename_axis('ports').reset_index(name='counts')

piechart_ports = np.unique(dstcounts_df['counts'].value_counts().to_numpy())

plt.figure(0)
ports0 = dstcounts_df['ports'][:10]
counts0 = dstcounts_df['counts'][:10]

fig0 = plt.figure(figsize =(10, 7)) 
plt.pie(counts0, labels = ports0) 

plt.figure(1)
ports1 = dstcounts_df['ports'][dstcounts_df.shape[0]-10:]
counts1 = dstcounts_df['counts'][dstcounts_df.shape[0]-10:]
  
# Creating plot 
fig1 = plt.figure(figsize =(10, 7)) 
plt.pie(counts1, labels = ports1)

plt.show()

# %% [markdown]
# Acima temos dois gráficos mostrando a proporção da quantidade de vezes que uma porta foi usada. O gráfico acima mostra as mais usadas. A porta 1883 foi usada muitas vezes, pois é usada pelo broker para receber os dados da rede.
#
# O gráfico abaixo mostra as menos usadas. É importante notar que todas essas portas foram usadas somente uma vez, o que é improvável para um dispositivo padrão pois ele utiliza a mesma porta para continuamente mandar seus dados em tempo real. É possível que a quantidade de vezes que uma porta alta foi utilizada possa determinar comportamento anormal na rede.

# %% [markdown]
# # 2.2 Continuidade das análises

# %% [markdown]
# # Chequando correlações para determinar ataques DoS

# %% [markdown]
# The following analysis uses only first_dataset.csv generated by subdataset notebook .

# %% [markdown]
# ## Analisando a correlação entre o tamanho do pacote e o tempo de resposta

# %%
#There's exactly one value in this column that goes beyond a  float64 which is weird but is ignored, probably it's the datatype
frame_delta = pd.to_numeric(df['frame.time_delta'], errors='coerce') 
packet_lenght = df['ipv6.plen']

correlation = frame_delta.corr(packet_lenght)
print(correlation)
# Out:
# 0.023931876963261923

# %% [markdown]
# ### Não existe correlação, isso se deve a fragmentação de pacotes, de acordo com a RFC8200 (https://tools.ietf.org/html/rfc8200) em jullho 2017, que padroniza o ipv6, o tamanho máximo de um pacote ipv6 é igual a MTU (maximum transmiter unit) do link de conexão, de acordo com a mesma, o minímo que uma rede ipv6 necessita de vazão de dados em um link de conexão é de 1280 bytes. O único caso em que um pacote não é fragmentado é quando ele excede o tamanho da MTU, nesse caso ele é transmitido por mais de uma MTU simultâneamente.
#
# ### Aqui checamos de algum pacote pode não ser fragmentado

# %%
df.loc[df['ipv6.plen'] >= 1280*8]
# Out:
# Empty DataFrame
# Columns: [frame.time_delta, frame.time_epoch, frame.time_relative, ipv6.plen, ipv6.nxt, ipv6.src, ipv6.dst, tcp.srcport, tcp.dstport, eth.src, eth.dst, frame.len, frame.number, mqtt.clientid, mqtt.dupflag, mqtt.hdrflags, mqtt.kalive, mqtt.len, mqtt.msg, mqtt.msgid, mqtt.msgtype, mqtt.passwd, mqtt.qos, mqtt.retain, mqtt.topic, mqtt.topic_len, mqtt.username, mqtt.willmsg, mqtt.willtopic, label]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ## Analisar correlação entre tamanho da mensagem e tempo de resposta

# %%
frame_delta = pd.to_numeric(df['frame.time_delta'], errors='coerce') 
mqtt_lenght = pd.to_numeric(df['mqtt.len'], errors='coerce')

correlation = mqtt_lenght.corr(packet_lenght)
print(correlation)
# Out:
# 0.9883822306472846

# %% [markdown]
# ### Essa correlação existe e é fácil de observar, mensagens maiores demoram mais tempo para serem processadas pelo servidor, entretanto a partir disso é possível buscar uma proporção com o tamanho da mensagem ou com o tempo de resposta e identificar se ataques de negação de serviço atingem tempos absurdos de tempo de resposta ou valores extremamente altos no tamanho da mensagem

# %% [markdown]
# ### Obs: Os valores do tempo de resposta são extremamente precisos em algumas tuplas, então estas foram excluidas dessas analises iniciais pois requerem um tratamento especial de dados.
#
# ### Tuplas excluídas:

# %%
df['frame.time_delta'] = pd.to_numeric(df['frame.time_delta'], errors='coerce')
df[df['frame.time_delta'].isnull()]
# Out:
#         frame.time_delta           frame.time_epoch  frame.time_relative  \
# 4                    NaN  1.573.757.296.060.980.000        3.291.717.000
# 8                    NaN  1.573.757.297.929.890.000        5.160.622.000
# 16                   NaN  1.573.757.300.414.100.000        7.644.834.000
# 20                   NaN  1.573.757.301.890.900.000        9.121.634.000
# 28                   NaN  1.573.757.306.102.290.000       13.333.029.000
# ...                  ...                        ...                  ...
# 670017               NaN  1.574.035.183.758.080.000  277.890.988.819.000
# 670021               NaN  1.574.035.187.101.560.000  277.894.332.296.000
# 670029               NaN  1.574.035.190.677.280.000  277.897.908.015.000
# 670041               NaN  1.574.035.193.774.270.000  277.901.005.005.000
# 670045               NaN  1.574.035.197.117.240.000  277.904.347.974.000
#
#         ipv6.plen  ipv6.nxt                              ipv6.src  \
# 4              68         6  fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b
# 8              68         6  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91
# 16             66         6  fd9e:6c51:2336:0:6ac6:3aff:fe99:4054
# 20             68         6  fd9e:6c51:2336:0:2ef4:32ff:fe19:85be
# 28             68         6  fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b
# ...           ...       ...                                   ...
# 670017         68         6  fd9e:6c51:2336:0:2ef4:32ff:fe19:85be
# 670021         68         6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
# 670029         66         6  fd9e:6c51:2336:0:6ac6:3aff:fe99:4054
# 670041         68         6  fd9e:6c51:2336:0:2ef4:32ff:fe19:85be
# 670045         68         6  fd9e:6c51:2336:0:6201:94ff:fe0e:877a
#
#                                     ipv6.dst  tcp.srcport  tcp.dstport  \
# 4       fd9e:6c51:2336:0:717b:e02b:9c00:d43a      60066.0       1883.0
# 8       fd9e:6c51:2336:0:717b:e02b:9c00:d43a      62795.0       1883.0
# 16      fd9e:6c51:2336:0:717b:e02b:9c00:d43a      60949.0       1883.0
# 20      fd9e:6c51:2336:0:717b:e02b:9c00:d43a      49673.0       1883.0
# 28      fd9e:6c51:2336:0:717b:e02b:9c00:d43a      60066.0       1883.0
# ...                                      ...          ...          ...
# 670017  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      49713.0       1883.0
# 670021  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      50746.0       1883.0
# 670029  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      60950.0       1883.0
# 670041  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      49713.0       1883.0
# 670045  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      50746.0       1883.0
#
#                   eth.src  ... mqtt.msgtype  mqtt.passwd  mqtt.qos  \
# 4       cc:50:e3:1c:2a:5b  ...            3          NaN         0
# 8       cc:50:e3:55:cd:91  ...            3          NaN         0
# 16      68:c6:3a:99:40:54  ...            3          NaN         0
# 20      2c:f4:32:19:85:be  ...            3          NaN         0
# 28      cc:50:e3:1c:2a:5b  ...            3          NaN         0
# ...                   ...  ...          ...          ...       ...
# 670017  2c:f4:32:19:85:be  ...            3          NaN         0
# 670021  60:01:94:0e:87:7a  ...            3          NaN         0
# 670029  68:c6:3a:99:40:54  ...            3          NaN         0
# 670041  2c:f4:32:19:85:be  ...            3          NaN         0
# 670045  60:01:94:0e:87:7a  ...            3          NaN         0
#
#        mqtt.retain                               mqtt.topic mqtt.topic_len  \
# 4                1  ufpi/ppgcc/esp-dht22-node03/temperatura             39
# 8                1  ufpi/ppgcc/esp-dht22-node01/temperatura             39
# 16               1  ufpi/ppgcc/esp-dht22-node08/temperatura             39
# 20               1  ufpi/ppgcc/esp-dht22-node04/temperatura             39
# 28               1  ufpi/ppgcc/esp-dht22-node03/temperatura             39
# ...            ...                                      ...            ...
# 670017           1  ufpi/ppgcc/esp-dht22-node04/temperatura             39
# 670021           1  ufpi/ppgcc/esp-dht22-node07/temperatura             39
# 670029           1  ufpi/ppgcc/esp-dht22-node08/temperatura             39
# 670041           1  ufpi/ppgcc/esp-dht22-node04/temperatura             39
# 670045           1  ufpi/ppgcc/esp-dht22-node07/temperatura             39
#
#         mqtt.username mqtt.willmsg mqtt.willtopic   label
# 4                 NaN          NaN            NaN  normal
# 8                 NaN          NaN            NaN  normal
# 16                NaN          NaN            NaN  normal
# 20                NaN          NaN            NaN  normal
# 28                NaN          NaN            NaN  normal
# ...               ...          ...            ...     ...
# 670017            NaN          NaN            NaN  normal
# 670021            NaN          NaN            NaN  normal
# 670029            NaN          NaN            NaN  normal
# 670041            NaN          NaN            NaN  normal
# 670045            NaN          NaN            NaN  normal
#
# [95642 rows x 30 columns]

# %%
#670052 100 
#95642 x
print(str((95642*100)/670052) + "% of the tuples were excluded in the first correlation")
# Out:
# 14.27381755445846% of the tuples were excluded in the first correlation

# %%
df['mqtt.len'] = pd.to_numeric(df['mqtt.len'], errors='coerce')
df[df['mqtt.len'].isnull()].loc[df['label'] != 'normal']
# Out:
#         frame.time_delta           frame.time_epoch  frame.time_relative  \
# 12218           0.318415  1.573.762.306.023.030.000    5.013.253.767.000
# 12219           0.000014  1.573.762.306.023.050.000    5.013.253.781.000
# 12220           0.002561  1.573.762.306.025.610.000    5.013.256.342.000
# 12222           0.750819  1.573.762.306.776.440.000    5.014.007.170.000
# 12224           0.003944  1.573.762.306.780.400.000    5.014.011.135.000
# ...                  ...                        ...                  ...
# 665018          0.000009  1.574.033.108.135.310.000  275.815.366.048.000
# 665019          0.588280  1.574.033.108.723.590.000  275.815.954.328.000
# 665020          0.000024  1.574.033.108.723.620.000  275.815.954.352.000
# 665021          0.002138  1.574.033.108.725.760.000  275.815.956.490.000
# 665022          0.000010  1.574.033.108.725.770.000  275.815.956.500.000
#
#         ipv6.plen  ipv6.nxt                              ipv6.src  \
# 12218          40         6  fd9e:6c51:2336:0:cdac:31e2:320d:90b6
# 12219          40         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 12220          32         6  fd9e:6c51:2336:0:cdac:31e2:320d:90b6
# 12222          32         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 12224          32         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# ...           ...       ...                                   ...
# 665018         32         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 665019         32         6  fd9e:6c51:2336:0:b043:1759:1f44:81e8
# 665020         32         6  fd9e:6c51:2336:0:b043:1759:1f44:81e8
# 665021         32         6  fd9e:6c51:2336:0:717b:e02b:9c00:d43a
# 665022         32         6  fd9e:6c51:2336:0:b043:1759:1f44:81e8
#
#                                     ipv6.dst  tcp.srcport  tcp.dstport  \
# 12218   fd9e:6c51:2336:0:717b:e02b:9c00:d43a      44245.0       1883.0
# 12219   fd9e:6c51:2336:0:cdac:31e2:320d:90b6       1883.0      44245.0
# 12220   fd9e:6c51:2336:0:717b:e02b:9c00:d43a      44245.0       1883.0
# 12222   fd9e:6c51:2336:0:cdac:31e2:320d:90b6       1883.0      44245.0
# 12224   fd9e:6c51:2336:0:cdac:31e2:320d:90b6       1883.0      44245.0
# ...                                      ...          ...          ...
# 665018  fd9e:6c51:2336:0:b043:1759:1f44:81e8       1883.0      42774.0
# 665019  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      42774.0       1883.0
# 665020  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      42780.0       1883.0
# 665021  fd9e:6c51:2336:0:b043:1759:1f44:81e8       1883.0      42780.0
# 665022  fd9e:6c51:2336:0:717b:e02b:9c00:d43a      42780.0       1883.0
#
#                   eth.src  ... mqtt.msgtype  mqtt.passwd  mqtt.qos  \
# 12218   80:86:f2:f9:f9:4d  ...          NaN          NaN       NaN
# 12219   30:b5:c2:4c:23:8a  ...          NaN          NaN       NaN
# 12220   80:86:f2:f9:f9:4d  ...          NaN          NaN       NaN
# 12222   30:b5:c2:4c:23:8a  ...          NaN          NaN       NaN
# 12224   30:b5:c2:4c:23:8a  ...          NaN          NaN       NaN
# ...                   ...  ...          ...          ...       ...
# 665018  68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 665019  80:86:f2:f9:f9:4d  ...          NaN          NaN       NaN
# 665020  80:86:f2:f9:f9:4d  ...          NaN          NaN       NaN
# 665021  68:a3:c4:6e:50:12  ...          NaN          NaN       NaN
# 665022  80:86:f2:f9:f9:4d  ...          NaN          NaN       NaN
#
#        mqtt.retain mqtt.topic mqtt.topic_len  mqtt.username  mqtt.willmsg  \
# 12218          NaN        NaN            NaN            NaN           NaN
# 12219          NaN        NaN            NaN            NaN           NaN
# 12220          NaN        NaN            NaN            NaN           NaN
# 12222          NaN        NaN            NaN            NaN           NaN
# 12224          NaN        NaN            NaN            NaN           NaN
# ...            ...        ...            ...            ...           ...
# 665018         NaN        NaN            NaN            NaN           NaN
# 665019         NaN        NaN            NaN            NaN           NaN
# 665020         NaN        NaN            NaN            NaN           NaN
# 665021         NaN        NaN            NaN            NaN           NaN
# 665022         NaN        NaN            NaN            NaN           NaN
#
#        mqtt.willtopic       label
# 12218             NaN  bruteforce
# 12219             NaN  bruteforce
# 12220             NaN  bruteforce
# 12222             NaN  bruteforce
# 12224             NaN  bruteforce
# ...               ...         ...
# 665018            NaN         DoS
# 665019            NaN         DoS
# 665020            NaN         DoS
# 665021            NaN         DoS
# 665022            NaN         DoS
#
# [105283 rows x 30 columns]

# %%
#670052 100 
#322215  x
print(str((105283*100)/670052) + "% of the tuples were excluded in the second correlation this may or may not overlap with the loss from the first correlation which is still present")
# Out:
# 15.712661106899166% of the tuples were excluded in the second correlation this may or may not overlap with the loss from the first correlation which is still present

# %% [markdown]
# ## 2.2.1 Categorizando ataques MITM

# %% [markdown]
# ### Em uma rede normal o relacionamento padrão entre endereço IP e MAC é de 1 para 1, ou seja, um IP aponta para um MAC e um MAC é apontado por somente um IP. Entretanto, em casos de ataque MITM, o atacante se passa por um dos nós da rede, para isso ele pode tanto copiar o MAC do dispostivo que ele deseja "escutar" ou mudar a tabela ARP da rede para resolver seu IP para o MAC do alvo.
#
# ### Aqui estamos agrupando os valores em questão para fazer uma breve análise sobre essa hipótese

# %%
df_.groupby(['eth.src', 'ipv6.src', 'label']).agg({'frame.time_delta': 'count'}).reset_index()
# Out:
#               eth.src                              ipv6.src        label  \
# 0   08:00:27:e4:e6:83                     fd9e:6c51:2336::1         mitm
# 1   08:00:27:e4:e6:83             fe80::32b5:c2ff:fe4c:238a         mitm
# 2   08:00:27:e4:e6:83             fe80::7a78:397a:82c6:761b         mitm
# 3   2c:f4:32:19:85:be  fd9e:6c51:2336:0:2ef4:32ff:fe19:85be       normal
# 4   30:b5:c2:4c:23:8a                     fd9e:6c51:2336::1         mitm
# 5   30:b5:c2:4c:23:8a                     fd9e:6c51:2336::1       normal
# 6   30:b5:c2:4c:23:8a             fe80::32b5:c2ff:fe4c:238a         mitm
# 7   30:b5:c2:4c:23:8a             fe80::32b5:c2ff:fe4c:238a       normal
# 8   60:01:94:0e:87:7a  fd9e:6c51:2336:0:6201:94ff:fe0e:877a       normal
# 9   68:a3:c4:6e:50:12  fd9e:6c51:2336:0:717b:e02b:9c00:d43a  enumeration
# 10  68:a3:c4:6e:50:12  fd9e:6c51:2336:0:717b:e02b:9c00:d43a       normal
# 11  68:c6:3a:99:40:54  fd9e:6c51:2336:0:6ac6:3aff:fe99:4054       normal
# 12  80:86:f2:f9:f9:4d  fd9e:6c51:2336:0:195a:4614:25ac:dd31         mitm
# 13  80:86:f2:f9:f9:4d  fd9e:6c51:2336:0:8477:491b:87c1:bd39         mitm
# 14  80:86:f2:f9:f9:4d  fd9e:6c51:2336:0:9873:f160:5832:6509  enumeration
# 15  80:86:f2:f9:f9:4d             fe80::4056:3a9a:e497:8e7d         mitm
# 16  80:86:f2:f9:f9:4d             fe80::7a78:397a:82c6:761b         mitm
# 17  cc:50:e3:1c:2a:5b  fd9e:6c51:2336:0:ce50:e3ff:fe1c:2a5b       normal
# 18  cc:50:e3:1c:2a:5b             fe80::ce50:e3ff:fe1c:2a5b       normal
# 19  cc:50:e3:1c:32:ec  fd9e:6c51:2336:0:ce50:e3ff:fe1c:32ec         mitm
# 20  cc:50:e3:1c:32:ec  fd9e:6c51:2336:0:ce50:e3ff:fe1c:32ec       normal
# 21  cc:50:e3:1c:32:ec             fe80::ce50:e3ff:fe1c:32ec         mitm
# 22  cc:50:e3:1c:32:ec             fe80::ce50:e3ff:fe1c:32ec       normal
# 23  cc:50:e3:55:cd:91  fd9e:6c51:2336:0:ce50:e3ff:fe55:cd91       normal
#
#     frame.time_delta
# 0               2144
# 1               1488
# 2               1560
# 3              22975
# 4               6226
# 5               1105
# 6               2704
# 7                116
# 8              22958
# 9               4276
# 10            140849
# 11             22572
# 12               240
# 13               704
# 14              4694
# 15               684
# 16             39062
# 17             21875
# 18               524
# 19               432
# 20             22975
# 21               816
# 22                 1
# 23             24613

# %% [markdown]
# ### Como pudemos observar, realmente o label MITM está relacionado com uma relação não padrão entre IP e MAC. Temos tanto mais de um IP resolvendo para o mesmo MAC quanto um IP com diferentes MACs ao longo da captura de pacotes da rede. Em todos os casos observados no gráfico, essa anomalia está associada à um ataque MITM. Então podemos investigar a detecção de tal ataque baseada nessa hipótese, também podemos treinar um algoritmo que escuta a rede durante determinado período e então com base nos pacotes escutados identifica o nó do invasor.
